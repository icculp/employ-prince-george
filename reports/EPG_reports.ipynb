# %% [markdown]
# <a href="https://colab.research.google.com/github/icculp/employ-prince-george/blob/main/reports/EPG_reports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymongo[srv]

# %%
import pymongo
import pandas as pd
from pymongo import MongoClient
from datetime import date, timedelta  
from google.colab import data_table

# %%
client = MongoClient("mongodb+srv://reports:reports@cluster0.3z5dy.mongodb.net/epg?retryWrites=true&w=majority")

# %%
mydb = client["epg"]
mycol = mydb["employers"]

# myquery = { "address": "Valley 345" }
# newvalues = { "$set": { "address": "Canyon 123" } }
print(mycol.find())
# mycol.update_one(myquery, newvalues)

# print "customers" after the update:
for x in mycol.find():
  print(x)
# Out:
# ...
# {'_id': ObjectId('62059946a88090c27fe840fe'), 'business_name': 'Water Transit Solutions', 'DBA': 'None', 'street_number': '1401', 'street': 'Mercantile Lane', 'suite': '400', 'city': 'Largo', 'zip': '20774', 'municipality': 'Yes', 'state': 'MD', 'industry_sector': 'Other', 'rrgrant': 'Yes', 'mwe_registration': 'yes', 'mwe_mappings': 'E40 - Employer Information & Support Service (May be used for phone and virtual contacts)', 'md_assessor': 'No', 'poc_name': 'Mel Forbes', 'poc_email': 'forbesm408@gmail.com', 'poc_phone': '2025593473', 'business_socials': 'Unknown', 'business_website': 'www.watertransitsolutions.com', 'business_length': '1to3', 'num_locations': '4', 'num_fulltime': 'None', 'num_parttime': '8', 'business_site': 'mixed', 'business_description': 'Clean water filtration and distribution', 'job_descriptions': 'None', 'hire_quantity': '5+', 'hire_timeframe': '1to3', 'hire_compensation': 'TBD', 'hire_skills': 'Administrative, computer software (MS Office), energetic, enthusias
# ...

# %%
db = client.epg
collection = db.employers
data = pd.DataFrame(list(collection.find()))
print("Grand total records: {}".format(collection.count_documents({})))
# Out:
# Grand total records: 7

# %%
data['date'] = pd.to_datetime(data['date'], unit='ms')  # Convert from epoch time to local

# %%
data = data.set_index('date')
data
# Out:
#                                           _id  ...                       minority
# date                                           ...
# 2022-02-10 23:01:08  62059946a88090c27fe840fe  ...                            Yes
# 2022-02-11 01:27:18  6205bb854813aee5ea2074dc  ...                            no
# 2022-02-11 01:29:32  6205bc014813aee5ea2074dd  ...                             No
# 2022-02-11 01:39:07  6205be3f4813aee5ea2074de  ...                            Yes
# 2022-02-11 13:57:13  62066b423b64cb328cde033f  ...                             No
# 2022-02-12 00:23:26  6206fe076e3e7469919ea68d  ...  Yes, woman and minority owned
# 2022-02-12 01:04:03  62070787e6ff4d76cff08ff3  ...            Yes, minority owned
#
# [7 rows x 39 columns]

# %% [markdown]
# **In the data table below, you can search any field with the Filter button in the top right of the cell**

# %%
#data_table.enable_dataframe_formatter()
data_table.DataTable.max_columns = 45

data_table.DataTable(data)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>_id</th>
#       <th>business_name</th>
#       <th>DBA</th>
#       <th>street_number</th>
#       <th>street</th>
#       <th>suite</th>
#       <th>city</th>
#       <th>zip</th>
#       <th>municipality</th>
#       <th>state</th>
#       <th>industry_sector</th>
#       <th>rrgrant</th>
#       <th>mwe_registration</th>
#       <th>mwe_mappings</th>
#       <th>md_assessor</th>
#       <th>poc_name</th>
#       <th>poc_email</th>
#       <th>poc_phone</th>
#       <th>business_socials</th>
#       <th>business_website</th>
#       <th>business_length</th>
#       <th>num_locations</th>
# ...

# %%
#week_prior = (date.today() - timedelta(weeks=1)).strftime("%Y-%d-%m")
#print(week_prior)
week_ago = pd.to_datetime(date.today() - timedelta(days=7))
print(week_ago)
within_last_week = data[data.index >= week_ago]
within_last_week
# Out:
# 2022-02-05 00:00:00
#                                           _id  ...                       minority
# date                                           ...
# 2022-02-10 23:01:08  62059946a88090c27fe840fe  ...                            Yes
# 2022-02-11 01:27:18  6205bb854813aee5ea2074dc  ...                            no
# 2022-02-11 01:29:32  6205bc014813aee5ea2074dd  ...                             No
# 2022-02-11 01:39:07  6205be3f4813aee5ea2074de  ...                            Yes
# 2022-02-11 13:57:13  62066b423b64cb328cde033f  ...                             No
# 2022-02-12 00:23:26  6206fe076e3e7469919ea68d  ...  Yes, woman and minority owned
# 2022-02-12 01:04:03  62070787e6ff4d76cff08ff3  ...            Yes, minority owned
#
# [7 rows x 39 columns]

# %%
total_engagements = len(within_last_week)
print("Total engagements: ", total_engagements)
# Out:
# Total engagements:  7

# %%
total_engagements_DC = sum(within_last_week['state'] == 'DC')
print("Total engagements from DC: ", total_engagements_DC)
# Out:
# Total engagements in DC:  4

# %%
total_engagements_MD = sum(within_last_week['state'] == 'MD')
print("Total engagements from MD: ", total_engagements_MD)
# Out:
# Total engagements from MD:  3

# %%
total_engagements_NOVA =  "Please clarify"

# %%
total_engagements_PG =  "Please clarify"

# %%
total_engagements_transportation_logistics = sum(within_last_week['industry_sector'] == 'Transportation') + sum(within_last_week['industry_sector'] == 'Logistics')
print("Total engagements from Transportation and Logistics: ", total_engagements_transportation_logistics)
# Out:
# Total engagements from Transportation and Logistics:  1

# %%
total_engagements_heathcare_hospitality = sum(within_last_week['industry_sector'] == 'Healthcare') + sum(within_last_week['industry_sector'] == 'Hospitality')
print("Total engagements from Heathcare and Hospitality: ", total_engagements_heathcare_hospitality)
# Out:
# Total engagements from Heathcare and Hospitality:  1

# %%
total_engagements_registered_EPG =  sum(within_last_week['industry_sector'] == 'Healthcare')
print("Total engagements: ", total_engagements)

# %%
total_engagements_registered_EPG_DC = 
print("Total engagements: ", total_engagements)

# %%
total_engagements_registered_EPG_NOVA =  "Please clarify"

# %%
total_engagements_registered_EPG_PG = "Please clarify"
